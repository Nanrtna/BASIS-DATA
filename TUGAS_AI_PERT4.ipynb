# %% [markdown]
# <a href="https://colab.research.google.com/github/Nanrtna/BASIS-DATA/blob/main/TUGAS_AI_PERT4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

Data = pd.read_excel("/content/DATA_SISWA_SMA(2).xlsx",header=1)
print(Data)

data = {'Nama': ['Chandra', 'Budi', 'Lussy', 'Yola', 'Nathan', 'Yanto', 'Faras', 'Gisella', 'Nanda', 'Melani'],
        'Berat Badan': [70, 67, 54, 58, 75, 66, 51, 56, 44, 49],
        'Tinggi Badan': [180, 187, 160, 156, 178, 167, 176, 186, 160, 157],
        'Ukuran': ['L', 'XL', 'S', 'S', 'L', 'L', 'XL', 'XL', 'S', 'S']}
df = pd.DataFrame(data)
plt.scatter(df['Berat Badan'], df['Tinggi Badan'])
plt.xlabel('Berat Badan')
plt.ylabel('Tinggi Badan')
plt.title('Hubungan Berat Badan dan Tinggi Badan')
plt.show()
# Out:
#   Nama Siswa/siswi  Berat Badan (kg)  Tinggi Badan (cm) Ukuran Baju
# 0          Chandra                70                180           L
# 1            Budi                 67                187          XL
# 2            Lussy                54                160           S
# 3             Yola                58                156           S
# 4          Nathan                 75                178           L
# 5           Yanto                 66                167           L
# 6            Faras                51                176          XL
# 7          Gisella                56                186          XL
# 8            Nanda                44                160           S
# 9           Melani                49                157           S
